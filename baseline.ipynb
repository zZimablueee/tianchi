# %% [markdown]
# baseline  ItemCF

# %%
import numpy as np
import pandas as pd
import os
import warnings
from tqdm import tqdm

data_path=r'C:\Users\Administrator\Desktop\tianchi'
save_path=r'C:\Users\Administrator\Desktop\tianchi\save'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
#节省内存函数
def reduce_mem(df):
    start_mem=df.memory_usage().sum()/1024**2
    print(f'Before:{start_mem:.2f} MB')
    for col in df.columns:
        col_type=df[col].dtype
        #不是字符串，即为数值类型
        if col_type!=object:
            c_min=df[col].min()
            c_max=df[col].max()
            if str(col_type).startwith('int'):
                if c_min>=np.iinfo(np.int8).min and c_max<=np.iinfo(np.int8).max:
                    df[col]=df[col].astype(np.int8)   
                elif c_min>=np.iinfo(np.int16).min and c_max<=np.iinfo(np.int16).max:
                    df[col]=df[col].astype(np.int16)
                elif c_min>=np.iinfo(np.int32).min and c_max<=np.iinfo(np.int32).max:
                    df[col]=df[col].astype(np.int32)
            elif str(col_type).startwith('float'):
                df[col]=df[col].astype(np.float32)
        
        #是字符串
        else:
            if df[col].nunique()/len(df[col])<0.5:
                df[col]=df[col].astype('category')
        
    end_mem=df.memory_usage().sum()/1024**2
    print(f'After:{end_mem:.2f} MB')
    print(f'Decreased:{(1-end_mem/start_mem)*100:.2f}%')

    return df
